# %%
import sys
import os

# Get the path to the directory above the current one
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))

if project_root not in sys.path:
    sys.path.append(project_root)

# 3. Double-check your current directory
print(f"Current Working Directory: {os.getcwd()}")
print(f"Project root added to path. You can now import.")
# Out:
# Current Working Directory: /content
# Project root added to path. You can now import.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data.dataset import Dataset
from torch.utils.data import DataLoader
import torchvision.models as models

# You'll need to install albumentations!
import albumentations as A
from albumentations.pytorch import ToTensorV2

import time
import os
import random
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import trange, tqdm
from PIL import Image, ImageOps
import copy
import pandas as pd

# %%
# ! pip uninstall urllib3
! pip install urllib3
# Out:
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.12/dist-packages (2.5.0)

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("gopalbhattrai/pascal-voc-2012-dataset")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'pascal-voc-2012-dataset' dataset.
# Path to dataset files: /kaggle/input/pascal-voc-2012-dataset

# %%
import os

# 1. Define source (Read-only) and target (Writable wrapper)
#    Note: We need to point to the actual VOCdevkit folder inside the input
input_root = '/kaggle/input/pascal-voc-2012-dataset'
target_root = '/content/VOCdevkit/VOC2012'

# 2. Create the destination directory structure (but not the final folder)
os.makedirs('/content/VOCdevkit', exist_ok=True)

# 3. Create the Symlink
#    This creates a "ghost" folder at target_root that points to input_root
if not os.path.exists(target_root):
    print(f"Creating symlink: {target_root} -> {input_root}")
    os.symlink(input_root, target_root)
    print("Success! (No copying required)")
else:
    print("Symlink already exists.")

# 4. Verify it works
print("\nVerifying structure...")
# !ls -F /content/VOCdevkit/
# Out:
# Creating symlink: /content/VOCdevkit/VOC2012 -> /kaggle/input/pascal-voc-2012-dataset
# Success! (No copying required)
#
# Verifying structure...
# VOC2012@

# %%
import shutil
import os

# The path you got from the download
cached_path = '/root/.cache/kagglehub/datasets/gopalbhattrai/pascal-voc-2012-dataset/versions/1'
target_path = '/content/VOCdevkit'

# Check if we already moved it to avoid errors
if not os.path.exists(target_path):
    print(f"Moving data from {cached_path} to {target_path}...")
    # We use move because it's instant (metadata change only)
    shutil.move(cached_path, target_path)
    print("Move complete!")
else:
    print("Data is already in /content/VOCdevkit")

# CRITICAL STEP: Kaggle datasets often have weird nesting.
# Let's find where the actual 'VOC2012' folder is hiding.
print("\nDirectory Structure:")
# !find /content/VOCdevkit -maxdepth 2 -type d
# Out:
# Data is already in /content/VOCdevkit
#
# Directory Structure:
# /content/VOCdevkit

# %%
from core.data_engine import VOCDataEngine

# One call to prepare the entire data pipeline
engine = VOCDataEngine(root_path='/content/VOCdevkit/VOC2012/VOC2012_train_val/VOC2012_train_val')
train_loader, val_loader = engine.get_loaders()
# Out:
# [Optimization] Pre-loading 1464 images and masks into RAM...
# 100%|██████████| 1464/1464 [03:09<00:00,  7.71it/s]
# [Optimization] Loading complete. Training loop is now unblocked.
#
#
# [Optimization] Pre-loading 1449 images and masks into RAM...
# 100%|██████████| 1449/1449 [03:04<00:00,  7.84it/s]
# [Optimization] Loading complete. Training loop is now unblocked.

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
class BaseSegmentationModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.history = {
            'train_loss': [], 'val_loss': [],
            'train_iou': [], 'val_iou': []
        }
        self.best_iou = 0.0

    def update_history(self, train_loss, val_loss, train_iou, val_iou):
        self.history['train_loss'].append(train_loss.item())
        self.history['val_loss'].append(val_loss.item())
        self.history['train_iou'].append(train_iou.item())
        self.history['val_iou'].append(val_iou.item())

    def save_checkpoint(self, path, epoch, iou):
        if iou > self.best_iou:
            self.best_iou = iou
            torch.save({
                'epoch': epoch,
                'model_state_dict': self.state_dict(),
                'history': self.history,
                'best_iou': self.best_iou
            }, path)
            print(f"--- Best Model Saved (mIoU: {iou:.4f}) ---")

# %%
# BASE U-NET MODEL
class UnetDown(nn.Module):
  def __init__(self, input_size, output_size):
    super().__init__()
    model = [
        nn.BatchNorm2d(input_size),
        nn.ELU(),
        nn.Conv2d(input_size, output_size, kernel_size=3, stride=1, padding=1),
        nn.BatchNorm2d(output_size),
        nn.ELU(),
        nn.MaxPool2d(kernel_size=2),
        nn.Conv2d(output_size, output_size, kernel_size=3, stride=1, padding=1)
    ]

    self.model = nn.Sequential(*model)

  def forward(self, x):
    return self.model(x)

class UnetUp(nn.Module):
  def __init__(self, input_size, output_size):
    super().__init__()

    model = [
        nn.BatchNorm2d(input_size),
        nn.ELU(),
        nn.Conv2d(input_size, output_size, kernel_size=3, stride=1, padding=1),
        nn.BatchNorm2d(output_size),
        nn.ELU(),
        nn.Upsample(scale_factor=2, mode="nearest"),
        nn.Conv2d(output_size, output_size, kernel_size=3, stride=1, padding=1)
    ]

    self.model = nn.Sequential(*model)

  def forward(self, x):
    return self.model(x)

class UnetV1(BaseSegmentationModel):
  def __init__(self, channels_in, channels_out=2):
    super().__init__()

    self.conv_in = nn.Conv2d(channels_in, 64,
                              kernel_size=3, stride=1, padding=1) # H X W --> H X W

    self.down1 = UnetDown(64, 64) # H X W --> H/2 X W/2
    self.down2 = UnetDown(64, 128) # H/2 X W/2 --> H/4 X W/4
    self.down3 = UnetDown(128, 128) # H/4 X W/4 --> H/8 X W/8
    self.down4 = UnetDown(128, 256) # H/8 X W/8 --> H/16 X W/16

    self.up1 = UnetUp(256, 128) # H/16 X W/16 --> H/8 X W/8
    self.up2 = UnetUp(128 *2, 128) # H/8 X W/8 --> H/4 X W/4
    self.up3 = UnetUp(128 *2, 64) # H/4 X W/4 --> H/2 X W/2
    self.up4 = UnetUp(64 *2, 64) # H/2 X W/2 --> H X W

    self.conv_out = nn.Conv2d(64 * 2, channels_out,
                              kernel_size=3, stride=1, padding=1) # H X W --> H X W

  def forward(self, x):
    x0 = self.conv_in(x) # 16 x H x W

    x1 = self.down1(x0) # 32 x H/2 x W/2
    x2 = self.down2(x1) # 64 x H/4 x W/4
    x3 = self.down3(x2) # 64 x H/8 x W/8
    x4 = self.down4(x3) # 128 x H/16 x W/16

    # Bottle-neck --> 128 x H/16 x W/16

    x5 = self.up1(x4) # 64 x H/8 x W/8

    x5_ = torch.cat((x5, x3), 1) # 128 x H/8 x W/8
    x6 = self.up2(x5_) # 32 x H/4 x W/4

    x6_ = torch.cat((x6, x2), 1) # 64 x H/4 x H/4
    x7 = self.up3(x6_) # 16 x H/2 x W/2

    x7_ = torch.cat((x7, x1), 1) # 64 x H/2 x W/2
    x8 = self.up4(x7_) # 16 x H x W

    x8_ = F.elu(torch.cat((x8, x0), 1)) # 32 x H x W
    return self.conv_out(x8_) # 2 x H x W

# %%
unetv1 = UnetV1(channels_in=3, channels_out=21)
device = "cuda" if torch.cuda.is_available() else "cpu"
unetv1 = unetv1.to(device)

# %%
# nn.Module class that will return IoU for a batch of outputs
class MulticlassIOU(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        self.num_classes = num_classes

    def forward(self, pred_mask, target_mask):
        """
        pred_logits: [Batch, 21, H, W] (Output of the model)
        target_mask: [Batch, H, W]     (Ground Truth)
        """

        # Loop over every class
        for cls_id in range(self.num_classes):
            # Create binary masks for this specific class
            pred_inds = (pred_mask == cls_id)
            target_inds = (target_mask == cls_id)

            # If this class is not in the target, skip it
            if target_inds.long().sum().item() == 0:
                continue

            # Calculate Intersection and Union using Logical operators
            intersection = (pred_inds & target_inds).sum().float()
            union = (pred_inds | target_inds).sum().float()

            # Avoid dividing by zero
            if union.item() != 0:
                return intersection / union

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
# TODO: In the explanations, explain the reason for choosing weight-based CrossEntropy over default CrossEntropy
class_weights = torch.ones(21).to(device)

class_weights[0] = 0.1

# Define loss function
loss_fn = nn.CrossEntropyLoss(weight=class_weights, ignore_index=255)

# Define optimizer
optimizer = torch.optim.Adam([
    dict(params=unetv1.parameters(), lr=0.001),
])

scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=15, gamma=0.1)

def iou_fn(y_true, y_pred):
    multiclassIOU = MulticlassIOU(num_classes=21)
    iou_score = multiclassIOU.forward(y_pred, y_true)
    return iou_score

# %%
import torch
import torch.nn as nn
from tqdm.auto import tqdm
from diagnostics.model_inspector import ModelInspector

# Attach Inspectors
inspector = ModelInspector(unetv1)
inspector.register_hooks()

print("--- STARTING DIAGNOSTIC RUN (1 Epoch, First Batch Only) ---")

# Run just ONE epoch (or break after 1 batch)
unetv1.train()

epochs = 5

for epoch in range(epochs):
  for batch, (X, y) in enumerate(train_loader):
      if epoch == 4 and batch == 0:
          X, y = X.to(device), y.to(device)

          # 1. Forward Pass (Triggers Forward Hooks)
          print(f"\nProcessing Batch {batch}...")
          y_pred = unetv1(X)

          # 2. Calculate Loss
          loss_ce = loss_fn(y_pred, y)
          total_loss = loss_ce

          # 3. Backward Pass (Triggers Backward Hooks)
          optimizer.zero_grad()
          total_loss.backward()

          # 4. REPORT AND STOP
          # We print the report immediately after the first backward pass
          inspector.print_report()

          # CRITICAL: Stop after n batch so you don't flood your console
          print(f"Diagnosis complete for Batch {batch}. Stopping.")

# Clean up hooks so they don't interfere with future runs
inspector.clear_hooks()
# Out:
# DEBUG: Attached inspectors to 34 layers.
# --- STARTING DIAGNOSTIC RUN (1 Epoch, First Batch Only) ---
#
# Processing Batch 0...
# sys:1: UserWarning: Full backward hook is firing when gradients are computed with respect to module outputs since no inputs require gradients. See https://docs.pytorch.org/docs/main/generated/torch.nn.Module.html#torch.nn.Module.register_full_backward_hook for more details.
# ============================================================
# LAYER (Forward)                | Mean       | Std        | Status
# ------------------------------------------------------------
# conv_in                        | 0.0167     | 0.6627     | OK
# down1.model.0                  | 0.0000     | 1.0000     | OK
# down1.model.2                  | 0.0055     | 0.4643     | OK
# down1.model.3                  | -0.0000     | 1.0000     | OK
# down1.model.6                  | 0.0250     | 0.5413     | OK
# down2.model.0                  | 0.0000     | 1.0000     | OK
# down2.model.2                  | 0.0064     | 0.4659     | OK
# down2.model.3                  | 0.0000     | 1.0000     | OK
# down2.model.6                  | -0.0164     | 0.6019     | OK
# down3.model.0                  | 0.0000     | 1.0000     | OK
# down3.model.2                  | -0.0151     | 0.4502     | OK
# down3.model.3                  | 0.0000     | 1.0000     | OK
# down3.model.6                  | 0.0308     | 0.6296     | OK
# down4.model.0                  | 0.0000     | 1.0000     | OK
# down4.model.2                  | -0.0078     | 0.4564     | OK
# down4.model.3                  | 0.0000     | 1.0000     | OK
# down4.model.6                  | -0.0160     | 0.5951     | OK
# up1.model.0                    | 0.0000     | 1.0000     | OK
# up1.model.2                    | -0.0076     | 0.4533     | OK
# up1.model.3                    | 0.0000     | 1.0000     | OK
# up1.model.6                    | 0.0021     | 0.4540     | OK
# up2.model.0                    | 0.0000     | 1.0000     | OK
# up2.model.2                    | -0.0097     | 0.4602     | OK
# up2.model.3                    | 0.0000     | 1.0000     | OK
# up2.model.6                    | -0.0012     | 0.4655     | OK
# up3.model.0                    | 0.0000     | 1.0000     | OK
# up3.model.2                    | -0.0049     | 0.4520     | OK
# up3.model.3                    | -0.0000     | 1.0000     | OK
# up3.model.6                    | 0.0124     | 0.4545     | OK
# up4.model.0                    | 0.0000     | 1.0000     | OK
# up4.model.2                    | 0.0012     | 0.4773     | OK
# up4.model.3                    | 0.0000     | 1.0000     | OK
# up4.model.6                    | 0.0073     | 0.4425     | OK
# conv_out                       | 0.0164     | 0.2783     | OK
#
# ------------------------------------------------------------
# LAYER (Backward/Gradients)     | Grad Mean    | Grad Max     | Status
# ------------------------------------------------------------
# conv_in                        | 5.58e-10   | 6.93e-05   | OK
# down1.model.0                  | 1.37e-11   | 1.29e-05   | OK
# down1.model.2                  | -2.78e-17   | 7.04e-05   | OK
# down1.model.3                  | 1.49e-11   | 1.57e-05   | OK
# down1.model.6                  | -3.89e-16   | 4.13e-05   | OK
# down2.model.0                  | 3.06e-11   | 1.29e-05   | OK
# down2.model.2                  | -6.94e-17   | 3.82e-05   | OK
# down2.model.3                  | -3.33e-11   | 1.51e-05   | OK
# down2.model.6                  | 6.11e-16   | 3.85e-05   | OK
# down3.model.0                  | -1.78e-11   | 1.37e-05   | OK
# down3.model.2                  | -4.44e-16   | 5.79e-05   | OK
# down3.model.3                  | 1.15e-10   | 2.00e-05   | OK
# down3.model.6                  | 3.11e-15   | 4.54e-05   | OK
# down4.model.0                  | -5.35e-10   | 1.83e-05   | OK
# down4.model.2                  | 1.11e-16   | 5.08e-05   | OK
# down4.model.3                  | 8.99e-11   | 2.32e-05   | OK
# down4.model.6                  | -1.78e-15   | 4.80e-05   | OK
# up1.model.0                    | -4.53e-10   | 2.10e-05   | OK
# up1.model.2                    | 0.00e+00   | 6.54e-05   | OK
# up1.model.3                    | -7.71e-11   | 2.70e-05   | OK
# up1.model.6                    | -4.44e-16   | 1.84e-05   | OK
# up2.model.0                    | -1.02e-10   | 8.45e-06   | OK
# up2.model.2                    | -4.44e-16   | 2.16e-05   | OK
# up2.model.3                    | -1.13e-10   | 9.88e-06   | OK
# up2.model.6                    | -4.44e-16   | 7.10e-06   | OK
# up3.model.0                    | -2.29e-11   | 2.85e-06   | OK
# up3.model.2                    | -2.22e-16   | 1.00e-05   | OK
# up3.model.3                    | 4.17e-11   | 4.40e-06   | OK
# up3.model.6                    | 2.22e-16   | 3.11e-06   | OK
# up4.model.0                    | 9.27e-11   | 1.32e-06   | OK
# up4.model.2                    | -2.50e-16   | 3.41e-06   | OK
# up4.model.3                    | 5.44e-09   | 1.34e-06   | OK
# up4.model.6                    | 3.15e-09   | 6.76e-07   | OK
# conv_out                       | -6.77e-16   | 3.70e-06   | OK
# ============================================================
#
# Diagnosis complete for Batch 0. Stopping.

# %%
from timeit import default_timer as timer

def print_train_time(start:float,
                     end: float,
                     device: torch.device=None):
  """Prints difference between start and end time."""
  total_time = end - start
  print(f"Train time on {device}: {total_time:.3f} seconds")
  return total_time

# %%
unetv1 = UnetV1(channels_in=3, channels_out=21)
device = "cuda" if torch.cuda.is_available() else "cpu"
unetv1 = unetv1.to(device)

# %%
import sys
import importlib
import core.training

# 1. Force a reload of the specific module
importlib.reload(core.training)

# 2. Re-import the classes to the global namespace
from core.training import Training, EarlyStopping

print("Memory Purged. StaticMethods should be active now.")
# Out:
# Memory Purged. StaticMethods should be active now.

# %% [markdown]
# If you come across `
# AssertionError: No inf checks were recorded for this optimizer.` error when running the training code, just restart optimizer after the model initiation. This error occurs because PyTorch requires model and optimizer be on the same device in order to do AMP.

# %%
torch.manual_seed(42)

from core.training import Training, EarlyStopping

training = Training()

# Measure time
from timeit import default_timer as timer
train_time_start_on_gpu = timer()

# Initialize early stopping
early_stopper = EarlyStopping(patience=7, min_delta=0.01)

# Set epochs
epochs = 50

# Create an optimizeation and evaluation loop using train_step() and valid_step()
for epoch in tqdm(range(epochs)):
  input_x, label_x = next(iter(train_loader))
  input_y, label_y = next(iter(val_loader))
  t_loss, t_iou = T=training.train_step(model=unetv1,
             data_loader=train_loader,
             loss_fn=loss_fn,
             optimizer=optimizer,
             accuracy_fn=iou_fn,
             device=device)
  v_loss, v_iou = training.valid_step(model=unetv1,
            data_loader=val_loader,
            loss_fn=loss_fn,
            optimizer=optimizer,
            accuracy_fn=iou_fn,
            device=device)

  unetv1.update_history(t_loss, v_loss, t_iou, v_iou)

  # 3. Check Early Stopping
  early_stopper(v_loss)
  if early_stopper.early_stop:
      unetv1.save_checkpoint("best_unet_v1.pth", epoch, v_iou)
      print(f"Early stopping at epoch {epoch}. Model is no longer improving.")
      break

train_time_end_on_gpu = timer()
total_train_time_model_1 = print_train_time(start=train_time_start_on_gpu,
                                            end=train_time_end_on_gpu,
                                            device=device)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Looked at 0/1464 samples
# Train loss: 2.70065 | Train acc: 58.72%
#
# Valid loss: 2.67269 | Valid acc: 52.41%
#
# Looked at 0/1464 samples
# Train loss: 2.58993 | Train acc: 63.05%
#
# Valid loss: 2.49050 | Valid acc: 63.37%
#
# Looked at 0/1464 samples
# Train loss: 2.53095 | Train acc: 63.95%
#
# Valid loss: 2.50627 | Valid acc: 62.21%
#
# EarlyStopping counter: 1 out of 7
# Looked at 0/1464 samples
# Train loss: 2.46209 | Train acc: 62.75%
#
# Valid loss: 2.60817 | Valid acc: 59.82%
#
# EarlyStopping counter: 2 out of 7
# Looked at 0/1464 samples
# Train loss: 2.44145 | Train acc: 64.29%
#
# Valid loss: 2.38366 | Valid acc: 60.27%
#
# Looked at 0/1464 samples
# Train loss: 2.40413 | Train acc: 64.62%
#
# Valid loss: 2.33755 | Valid acc: 58.68%
#
# Looked at 0/1464 samples
# Train loss: 2.35682 | Train acc: 65.29%
#
# Valid loss: 2.32468 | Valid acc: 59.64%
#
# Looked at 0/1464 samples
# Train loss: 2.32992 | Train acc: 65.68%
#
# Valid loss: 2.25265 | Valid acc: 61.45%
#
# Looked at 0/1464 samples
# Train loss: 2.26929 | Train acc: 66.10%
#
# Valid loss: 2.18558 | Valid acc: 64.20%
#
# Looked at 0/1464 samples
# Train loss: 2.26387 | Train acc: 65.23%
#
# Valid loss: 2.33955 | Valid acc: 64.57%
#
# EarlyStopping counter: 1 out of 7
# Looked at 0/1464 samples
# Train loss: 2.25433 | Train acc: 65.17%
#
# Valid loss: 2.18279 | Valid acc: 67.52%
#
# EarlyStopping counter: 2 out of 7
# Looked at 0/1464 samples
# Train loss: 2.21756 | Train acc: 66.00%
#
# Valid loss: 2.21847 | Valid acc: 65.63%
#
# EarlyStopping counter: 3 out of 7
# Looked at 0/1464 samples
# Train loss: 2.19563 | Train acc: 66.29%
#
# Valid loss: 2.16088 | Valid acc: 64.33%
#
# Looked at 0/1464 samples
# Train loss: 2.18834 | Train acc: 66.14%
#
# Valid loss: 2.20671 | Valid acc: 59.34%
#
# EarlyStopping counter: 1 out of 7
# Looked at 0/1464 samples
# Train loss: 2.14531 | Train acc: 65.76%
#
# Valid loss: 2.26446 | Valid acc: 63.62%
#
# EarlyStopping counter: 2 out of 7
# Looked at 0/1464 samples
# Train loss: 2.18594 | Train acc: 65.72%
#
# Valid loss: 2.11741 | Valid acc: 67.61%
#
# Looked at 0/1464 samples
# Train loss: 2.15523 | Train acc: 66.30%
#
# Valid loss: 2.22823 | Valid acc: 66.67%
#
# EarlyStopping counter: 1 out of 7
# Looked at 0/1464 samples
# Train loss: 2.13993 | Train acc: 65.91%
#
# Valid loss: 2.18800 | Valid acc: 66.29%
#
# EarlyStopping counter: 2 out of 7
# Looked at 0/1464 samples
# Train loss: 2.14790 | Train acc: 65.83%
#
# Valid loss: 2.24262 | Valid acc: 56.24%
#
# EarlyStopping counter: 3 out of 7
# Looked at 0/1464 samples
# Train loss: 2.11731 | Train acc: 66.22%
#
# Valid loss: 2.12860 | Valid acc: 66.58%
#
# EarlyStopping counter: 4 out of 7
# Looked at 0/1464 samples
# Train loss: 2.10875 | Train acc: 67.02%
#
# Valid loss: 2.07723 | Valid acc: 61.71%
#
# Looked at 0/1464 samples
# Train loss: 2.12879 | Train acc: 66.40%
#
# Valid loss: 2.20262 | Valid acc: 66.81%
#
# EarlyStopping counter: 1 out of 7
# Looked at 0/1464 samples
# Train loss: 2.07840 | Train acc: 66.56%
#
# Valid loss: 2.09479 | Valid acc: 67.43%
#
# EarlyStopping counter: 2 out of 7
# Looked at 0/1464 samples
# Train loss: 2.08644 | Train acc: 66.77%
#
# Valid loss: 2.17577 | Valid acc: 68.26%
#
# EarlyStopping counter: 3 out of 7
# Looked at 0/1464 samples
# Train loss: 2.08807 | Train acc: 67.84%
#
# Valid loss: 2.11370 | Valid acc: 63.79%
#
# EarlyStopping counter: 4 out of 7
# Looked at 0/1464 samples
# Train loss: 2.05929 | Train acc: 67.62%
#
# Valid loss: 2.15594 | Valid acc: 64.24%
#
# EarlyStopping counter: 5 out of 7
# Looked at 0/1464 samples
# Train loss: 2.08275 | Train acc: 67.26%
#
# Valid loss: 2.08604 | Valid acc: 68.00%
#
# EarlyStopping counter: 6 out of 7
# Looked at 0/1464 samples
# Train loss: 2.03714 | Train acc: 67.33%
#
# Valid loss: 2.08174 | Valid acc: 68.26%
#
# EarlyStopping counter: 7 out of 7
# --- Best Model Saved (mIoU: 0.6826) ---
# Early stopping at epoch 27. Model is no longer improving.
# Train time on cuda: 911.255 seconds

# %%
def plot_evolution(data, target, predictions, titles, num_classes=21):
    """
    data: Original image [C, H, W]
    target: Ground truth mask [H, W]
    predictions: List of model outputs or masks
    titles: List of titles for each prediction (e.g., ["Baseline", "Weighted CE"])
    """
    num_plots = 2 + len(predictions)
    fig, axes = plt.subplots(1, num_plots, figsize=(5 * num_plots, 5))
    cmap = plt.get_cmap('tab20', num_classes)

    # 1. Original Image
    img = data[0].permute(1, 2, 0).cpu().numpy().squeeze()
    # Add denormalization logic here if you used transforms.Normalize
    axes[0].imshow(img)
    axes[0].set_title("Original Image")

    # 2. Ground Truth
    axes[1].imshow(target[0].cpu(), cmap=cmap, vmin=0, vmax=num_classes-1)
    axes[1].set_title("Ground Truth")

    # 3. Model Predictions
    for i, pred in enumerate(predictions):
        mask = pred[0].cpu().numpy()
        axes[i+2].imshow(mask, cmap=cmap, vmin=0, vmax=num_classes-1)
        axes[i+2].set_title(titles[i])

    for ax in axes:
        ax.axis('off')

    plt.tight_layout()
    plt.show()

# %%
checkpoint = torch.load('best_unet_v1.pth', weights_only=True)
unetv1.load_state_dict(checkpoint['model_state_dict'])
unetv1.eval()
# Out:
# UnetV1(
#   (conv_in): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (down1): UnetDown(
#     (model): Sequential(
#       (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): ELU(alpha=1.0)
#       (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): ELU(alpha=1.0)
#       (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (6): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (down2): UnetDown(
#     (model): Sequential(
#       (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): ELU(alpha=1.0)
#       (2): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): ELU(alpha=1.0)
#       (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (6): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (down3): UnetDown(
#     (model): Sequential(
#       (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): ELU(alpha=1.0)
#       (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): ELU(alpha=1.0)
#       (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (6): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (down4): UnetDown(
#     (model): Sequential(
#       (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): ELU(alpha=1.0)
#       (2): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): ELU(alpha=1.0)
#       (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (6): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (up1): UnetUp(
#     (model): Sequential(
#       (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): ELU(alpha=1.0)
#       (2): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): ELU(alpha=1.0)
#       (5): Upsample(scale_factor=2.0, mode='nearest')
#       (6): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (up2): UnetUp(
#     (model): Sequential(
#       (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): ELU(alpha=1.0)
#       (2): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): ELU(alpha=1.0)
#       (5): Upsample(scale_factor=2.0, mode='nearest')
#       (6): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (up3): UnetUp(
#     (model): Sequential(
#       (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): ELU(alpha=1.0)
#       (2): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): ELU(alpha=1.0)
#       (5): Upsample(scale_factor=2.0, mode='nearest')
#       (6): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (up4): UnetUp(
#     (model): Sequential(
#       (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): ELU(alpha=1.0)
#       (2): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): ELU(alpha=1.0)
#       (5): Upsample(scale_factor=2.0, mode='nearest')
#       (6): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
#   (conv_out): Conv2d(128, 21, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )

# %%
valid_iter = iter(val_loader)

# %%
# Get one batch from validation
data, target = next(valid_iter)
unetv1.eval()
output = unetv1(data.to(device))
pred = output.argmax(dim=1) # Convert probabilities to class labels


plot_evolution(data, target, [pred], ["UnetV1"])
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.0494049..2.5179956].

# %% [markdown]
# Weighted `nn.CrossEntropyLoss` is great at pixel-level classification, which is why the shape(the silhoutte) is so accurate. But because it treats each pixel as an independent calculation, it does not know that a "motorcylce" pixel should be surrounded by other "motorcycle" pixels. To avoid this issue I focused on two other loss functions:
#
# **Focal Loss** - To handle the hard-to-classify pixels and prevent background from dominating the gradient without having to use a hard-coded weight
# **Dice Loss** - This is the game-changer for "hallucinations". Since Dice Loss looks at the **Intersection over Union(IoU)** of the entire class mask, it penalizes the model for having tiny "islands" of wrong classes inside a shape. It forces the model to be spatially consistent.
#
# You can check `UnetV2.ipynb` for the application and results of the addition of Focal Loss and Dice Loss.

# %%
def plot_metrics(history):
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))

    # Loss Plot
    axes[0].plot(history['train_loss'], label='Train Loss')
    axes[0].plot(history['val_loss'], label='Val Loss')
    axes[0].set_title('CrossEntropy Loss Evolution')
    axes[0].set_xlabel('Epoch')
    axes[0].legend()

    # IoU Plot
    axes[1].plot(history['train_iou'], label='Train mIoU')
    axes[1].plot(history['val_iou'], label='Val mIoU')
    axes[1].set_title('Mean IoU Evolution')
    axes[1].set_xlabel('Epoch')
    axes[1].legend()

    plt.show()

plot_metrics(unetv1.history)
